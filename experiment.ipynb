# %%
import networkx as nx
import matplotlib.pyplot as plt

# Build graph based on the Mermaid structure (condensed but still connected and fairly rich)
G = nx.DiGraph()

nodes = [
    "Invention",
    "Technical Field: Communications",
    "Background: DC Networking Pressure",
    "Data Center (DC)",
    "Server",
    "Storage Device",
    "Network Device",
    "Data Center Interconnect (DCI)",
    "DCI Goal: High-speed/reliable/secure",
    "DCI Req: High bandwidth + Low latency",
    "Traffic Growth Drivers",
    "Internet",
    "Cloud Services",
    "Big Data",
    "AI / AIGC",
    "AIGC Workloads",
    "Text/Image Generation",
    "Audio/Video Generation",
    "Effect: Exponential compute + traffic",
    "Hardware Limitation",
    "Main Control Board",
    "Interface Board",
    "Network Board",
    "Constraint: Limited capacity / non-expandable",
    "Impact: Forwarding can't keep up",
    "Problem: Increased latency",
    "Problem: Packet loss",
    "System: Cloud Cluster Switch",
    "Member Device",
    "NCC",
    "NCF",
    "NCP",
    "Method 1: Packet Processing",
    "Step: Determine Identity",
    "Branch: First NCP",
    "First Protocol Packet",
    "First Port",
    "Local Port Info",
    "Action: Add Local Port Info",
    "Second Protocol Packet",
    "Transmit to NCC",
    "Branch: NCC",
    "Action: Determine Global Port Info",
    "Global Port Info",
    "Action: Establish Forwarding Entry",
    "Forwarding Entry",
    "Entry: Server Address Info",
    "Entry: Global Port Info",
    "Transmit Entry to First NCP",
    "Runtime: NCP receives Data Packet",
    "Data Packet",
    "Destination Address",
    "Query Entry by Dest Address",
    "Transmit Data Packet via First Port",
    "Method 2: Resource Management",
    "Obtain Target Resource Data",
    "Network element-level resource data",
    "Network-level resource data",
    "Application-level resource data",
    "Service resource data",
    "Obtain User Initial Demand",
    "Initial demand = expected occupied resources",
    "Determine Target Demand",
    "Target demand = actually allocated",
    "Transmit Target Demand to Switch",
    "When switch receives user packet",
    "Allocate available resources",
    "Process packet with resources",
    "Apparatus: Packet Processing Apparatus",
    "Modules",
    "Determining Module",
    "Receiving Module",
    "Processing Module",
    "Transmitting Module",
]

G.add_nodes_from(nodes)

edges = [
    ("Invention","Technical Field: Communications"),
    ("Invention","Background: DC Networking Pressure"),
    ("Background: DC Networking Pressure","Data Center (DC)"),
    ("Data Center (DC)","Server"),
    ("Data Center (DC)","Storage Device"),
    ("Data Center (DC)","Network Device"),
    ("Background: DC Networking Pressure","Data Center Interconnect (DCI)"),
    ("Data Center Interconnect (DCI)","DCI Goal: High-speed/reliable/secure"),
    ("DCI Goal: High-speed/reliable/secure","DCI Req: High bandwidth + Low latency"),
    ("Background: DC Networking Pressure","Traffic Growth Drivers"),
    ("Traffic Growth Drivers","Internet"),
    ("Traffic Growth Drivers","Cloud Services"),
    ("Traffic Growth Drivers","Big Data"),
    ("Traffic Growth Drivers","AI / AIGC"),
    ("AI / AIGC","AIGC Workloads"),
    ("AIGC Workloads","Text/Image Generation"),
    ("AIGC Workloads","Audio/Video Generation"),
    ("AIGC Workloads","Effect: Exponential compute + traffic"),
    ("Background: DC Networking Pressure","Hardware Limitation"),
    ("Hardware Limitation","Main Control Board"),
    ("Hardware Limitation","Interface Board"),
    ("Hardware Limitation","Network Board"),
    ("Hardware Limitation","Constraint: Limited capacity / non-expandable"),
    ("Constraint: Limited capacity / non-expandable","Impact: Forwarding can't keep up"),
    ("Impact: Forwarding can't keep up","Problem: Increased latency"),
    ("Impact: Forwarding can't keep up","Problem: Packet loss"),
    ("Invention","System: Cloud Cluster Switch"),
    ("System: Cloud Cluster Switch","Member Device"),
    ("Member Device","NCC"),
    ("Member Device","NCF"),
    ("Member Device","NCP"),
    ("Invention","Method 1: Packet Processing"),
    ("Method 1: Packet Processing","Step: Determine Identity"),
    ("Step: Determine Identity","Branch: First NCP"),
    ("Branch: First NCP","First Protocol Packet"),
    ("First Protocol Packet","First Port"),
    ("First Port","Local Port Info"),
    ("Local Port Info","Action: Add Local Port Info"),
    ("Action: Add Local Port Info","Second Protocol Packet"),
    ("Second Protocol Packet","Transmit to NCC"),
    ("Transmit to NCC","NCC"),
    ("Step: Determine Identity","Branch: NCC"),
    ("Branch: NCC","Second Protocol Packet"),
    ("Second Protocol Packet","Action: Determine Global Port Info"),
    ("Action: Determine Global Port Info","Global Port Info"),
    ("Global Port Info","Action: Establish Forwarding Entry"),
    ("Action: Establish Forwarding Entry","Forwarding Entry"),
    ("Forwarding Entry","Entry: Server Address Info"),
    ("Forwarding Entry","Entry: Global Port Info"),
    ("Forwarding Entry","Transmit Entry to First NCP"),
    ("Transmit Entry to First NCP","NCP"),
    ("NCP","Runtime: NCP receives Data Packet"),
    ("Runtime: NCP receives Data Packet","Data Packet"),
    ("Data Packet","Destination Address"),
    ("Destination Address","Query Entry by Dest Address"),
    ("Query Entry by Dest Address","Forwarding Entry"),
    ("Query Entry by Dest Address","Transmit Data Packet via First Port"),
    ("Transmit Data Packet via First Port","First Port"),
    ("Invention","Method 2: Resource Management"),
    ("Method 2: Resource Management","Obtain Target Resource Data"),
    ("Obtain Target Resource Data","Network element-level resource data"),
    ("Obtain Target Resource Data","Network-level resource data"),
    ("Obtain Target Resource Data","Application-level resource data"),
    ("Obtain Target Resource Data","Service resource data"),
    ("Method 2: Resource Management","Obtain User Initial Demand"),
    ("Obtain User Initial Demand","Initial demand = expected occupied resources"),
    ("Method 2: Resource Management","Determine Target Demand"),
    ("Obtain Target Resource Data","Determine Target Demand"),
    ("Obtain User Initial Demand","Determine Target Demand"),
    ("Determine Target Demand","Target demand = actually allocated"),
    ("Method 2: Resource Management","Transmit Target Demand to Switch"),
    ("Determine Target Demand","Transmit Target Demand to Switch"),
    ("Transmit Target Demand to Switch","System: Cloud Cluster Switch"),
    ("System: Cloud Cluster Switch","When switch receives user packet"),
    ("When switch receives user packet","Allocate available resources"),
    ("Allocate available resources","Process packet with resources"),
    ("Process packet with resources","Method 1: Packet Processing"),  # tie between methods
    ("Invention","Apparatus: Packet Processing Apparatus"),
    ("Apparatus: Packet Processing Apparatus","Modules"),
    ("Modules","Determining Module"),
    ("Modules","Receiving Module"),
    ("Modules","Processing Module"),
    ("Modules","Transmitting Module"),
    ("Determining Module","Step: Determine Identity"),
    ("Receiving Module","First Protocol Packet"),
    ("Processing Module","Action: Add Local Port Info"),
    ("Transmitting Module","Transmit to NCC"),
    ("Processing Module","Action: Determine Global Port Info"),
    ("Processing Module","Action: Establish Forwarding Entry"),
    ("Transmitting Module","Transmit Entry to First NCP"),
]

G.add_edges_from(edges)

# Layout
from networkx.drawing.nx_pydot import graphviz_layout
pos = graphviz_layout(G, prog="dot")
# Draw and save to PDF + PNG
plt.figure(figsize=(22, 16))
nx.draw_networkx_edges(G, pos, arrows=True, arrowstyle='-|>', arrowsize=10, width=0.8, alpha=0.5)
nx.draw_networkx_nodes(G, pos, node_size=650, alpha=0.9)
nx.draw_networkx_labels(G, pos, font_size=7)

plt.axis("off")

plt.tight_layout()

plt.close()

(pdf_path, png_path, G.number_of_nodes(), G.number_of_edges())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Caleb\Documents\LLM Patent Claim Generator Thesis\.venv\Lib\site-packages\pydot\core.py:1824, in Dot.create(self, prog, format, encoding)
#    1823 try:
# -> 1824     stdout_data, stderr_data, process = call_graphviz(
#    1825         program=prog,
#    1826         arguments=arguments,
#    1827         working_dir=tmp_dir,
#    1828     )
#    1829 except OSError as e:
#
# File c:\Users\Caleb\Documents\LLM Patent Claim Generator Thesis\.venv\Lib\site-packages\pydot\core.py:249, in call_graphviz(program, arguments, working_dir, **kwargs)
#     247 program_with_args = [program] + arguments
# --> 249 process = subprocess.Popen(
#     250     program_with_args,
#     251     env=env,
#     252     cwd=working_dir,
#     253     shell=False,
#     254     stderr=subprocess.PIPE,
#     255     stdout=subprocess.PIPE,
# ...
